# %% [markdown]
# Dünyanın en hızlı en yavaş internetlerini listeleyeceğiz

# %%
#dataframe yapıyor yani bu sistemde bizim verilerle çalışabileceğimizi sağlıyor(excel gibi)
import pandas as pd

# %%
#internet.csv dosyasını çalıştırıyoruz.
internet = pd.read_csv('internet.csv')

# %%
internet
# Out:
#              Country  Broadband Speed Rank  Broadband Mbps  Mobile Speed Rank  \
# 0             Monaco                   1.0          192.68                NaN
# 1          Singapore                   2.0          192.01               19.0
# 2              Chile                   3.0          189.36              109.0
# 3           Thailand                   4.0          184.03               56.0
# 4    Hong Kong (SAR)                   5.0          173.42               38.0
# ..               ...                   ...             ...                ...
# 174            Yemen                 175.0            2.74              140.0
# 175         Ethiopia                 176.0            2.69               78.0
# 176             Cuba                 177.0            1.90              119.0
# 177     Turkmenistan                 178.0            1.89              139.0
# 178      Afghanistan                 179.0            1.62              138.0
#
#      Mobile Mbps         As of
# ...

# %%
def hizgetir(ulke):
  veri =  internet[internet['Country']==ulke]
  return veri

# %%
hizgetir("Turkey")
# Out:
#     Country  Broadband Speed Rank  Broadband Mbps  Mobile Speed Rank  \
# 102  Turkey                 103.0           26.34               58.0
#
#      Mobile Mbps         As of
# 102        32.28  January 2022

# %%
internet[internet['Mobile Mbps'] > internet['Broadband Mbps']]
# Out:
#                               Country  Broadband Speed Rank  Broadband Mbps  \
# 14               United Arab Emirates                  15.0          111.79
# 16                             Norway                  17.0          105.61
# 17                        Netherlands                  18.0          102.60
# 22                        South Korea                  23.0           99.59
# 40                       Saudi Arabia                  41.0           79.32
# 42                              Qatar                  43.0           72.22
# 54                           Bulgaria                  55.0           55.90
# 57                            Estonia                  58.0           52.30
# 58                            Austria                  59.0           51.62
# 60                          Australia                  61.0           50.89
# 77                               Oman                  78.0           42.65
# ...

# %%
internet['Ortalama']=(internet['Mobile Mbps']+internet['Broadband Mbps'])/2

# %%
internet
# Out:
#              Country  Broadband Speed Rank  Broadband Mbps  Mobile Speed Rank  \
# 0             Monaco                   1.0          192.68                NaN
# 1          Singapore                   2.0          192.01               19.0
# 2              Chile                   3.0          189.36              109.0
# 3           Thailand                   4.0          184.03               56.0
# 4    Hong Kong (SAR)                   5.0          173.42               38.0
# ..               ...                   ...             ...                ...
# 174            Yemen                 175.0            2.74              140.0
# 175         Ethiopia                 176.0            2.69               78.0
# 176             Cuba                 177.0            1.90              119.0
# 177     Turkmenistan                 178.0            1.89              139.0
# 178      Afghanistan                 179.0            1.62              138.0
#
# ...

# %%
ort=internet['Broadband Mbps'].mean()

# %%
internet[internet['Broadband Mbps']>ort]
# Out:
#             Country  Broadband Speed Rank  Broadband Mbps  Mobile Speed Rank  \
# 0            Monaco                   1.0          192.68                NaN
# 1         Singapore                   2.0          192.01               19.0
# 2             Chile                   3.0          189.36              109.0
# 3          Thailand                   4.0          184.03               56.0
# 4   Hong Kong (SAR)                   5.0          173.42               38.0
# ..              ...                   ...             ...                ...
# 66      Philippines                  67.0           49.52               92.0
# 67           Serbia                  68.0           48.97               43.0
# 68          Czechia                  69.0           47.68               40.0
# 69          Bahrain                  70.0           47.38               39.0
# 70         Slovakia                  71.0           47.34               59.0
#
#     Mobile Mbps         As of  Ortalama
# ...

# %%
internet.head()
# Out:
#            Country  Broadband Speed Rank  Broadband Mbps  Mobile Speed Rank  \
# 0           Monaco                   1.0          192.68                NaN
# 1        Singapore                   2.0          192.01               19.0
# 2            Chile                   3.0          189.36              109.0
# 3         Thailand                   4.0          184.03               56.0
# 4  Hong Kong (SAR)                   5.0          173.42               38.0
#
#    Mobile Mbps         As of  Ortalama
# 0          NaN  January 2022       NaN
# 1        64.92  January 2022   128.465
# 2        15.50  January 2022   102.430
# 3        32.38  January 2022   108.205
# 4        45.86  January 2022   109.640

# %%
internet.tail()
# Out:
#           Country  Broadband Speed Rank  Broadband Mbps  Mobile Speed Rank  \
# 174         Yemen                 175.0            2.74              140.0
# 175      Ethiopia                 176.0            2.69               78.0
# 176          Cuba                 177.0            1.90              119.0
# 177  Turkmenistan                 178.0            1.89              139.0
# 178   Afghanistan                 179.0            1.62              138.0
#
#      Mobile Mbps         As of  Ortalama
# 174         0.53  January 2022     1.635
# 175        22.83  January 2022    12.760
# 176        12.71  January 2022     7.305
# 177         3.09  January 2022     2.490
# 178         5.10  January 2022     3.360
